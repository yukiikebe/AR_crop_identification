# %%
# Public dataset
#read the pickle file
import pickle
import numpy as np

file_path = '/home/vuonghn/research/code/Agriculture/time-series-seg/DeepSatModels/datasets/PASTIS24/pickle24x24/10000_0.pickle'
with open(file_path, 'rb') as f:
    data = pickle.load(f)

print("keys value ", data.keys())
########
print("img shape ",data['img'].shape)
print("labels shape ",data['labels'].shape)
print("day of years ", data['doy'])
# same_values = np.array_equal(data['labels'][0], data['labels'][1]) and np.array_equal(data['labels'][1], data['labels'][2])
# print("data['labels'][0] ", data['labels'][0])

# print("\ndata['labels'][1] ", data['labels'][1])
# print("\nsame_values ", same_values)
# Out:
# keys value  dict_keys(['img', 'labels', 'doy'])
# img shape  (43, 10, 24, 24)
# labels shape  (3, 24, 24)
# day of years  [ 17  22  47  52  57  72  87 102 112 117 132 147 152 157 172 177 182 187
#  192 197 212 222 227 232 237 242 247 257 262 267 267 272 277 282 282 292
#  292 297 302 312 317 322 327]

# %%
#Our dataset
import pickle
import numpy as np

file_path = '/home/vuonghn/research/dataset/satellite/arkansas/dataset_final/0.pickle'
with open(file_path, 'rb') as f:
    our_data = pickle.load(f)

print("keys value ",our_data.keys())
########

print("img x10 shape ",our_data['x10'].shape)
print("img x20 shape ", our_data['x20'].shape)
print("img x60 shape ", our_data['x60'].shape)
print("day ",our_data['day'])
print("year ", our_data['year'])
print("label ", our_data['label'].shape)
# Out:
# keys value  dict_keys(['x10', 'x20', 'x60', 'day', 'year', 'label'])
# img x10 shape  (24, 24, 24, 6)
# img x20 shape  (24, 12, 12, 6)
# img x60 shape  (24, 4, 4, 3)
# day  [231, 233, 236, 241, 243, 251, 251, 253, 258, 261, 266, 271, 273, 281, 283, 291, 293, 303, 306, 308, 311, 326, 331, 343]
# year  ['2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023']
# label  (24, 24, 24)

# %%
# Out:
# keys value  dict_keys(['x10', 'x20', 'x60', 'day', 'year', 'label'])
# img x10 shape  (24, 24, 24, 6)
# img x20 shape  (24, 12, 12, 6)
# img x60 shape  (24, 4, 4, 3)
# day  [231, 233, 236, 241, 243, 251, 251, 253, 258, 261, 266, 271, 273, 281, 283, 291, 293, 303, 306, 308, 311, 326, 331, 343]
# year  ['2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023']
# label  (24, 24, 24)
