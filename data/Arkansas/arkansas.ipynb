# %%
# Public dataset
#read the pickle file
import pickle
import numpy as np

file_path = '/home/vuonghn/research/code/Agriculture/time-series-seg/DeepSatModels/datasets/PASTIS24/pickle24x24/10000_0.pickle'

with open(file_path, 'rb') as f:
    data = pickle.load(f)

print("keys value ", data.keys())
########
print("img shape ",data['img'].shape,data['img'].dtype)
print("labels shape ",data['labels'].shape, np.unique(data['labels']), data['labels'].dtype)
print("day of years ", data['doy'])
# Out:
# keys value  dict_keys(['img', 'labels', 'doy'])
# img shape  (43, 10, 24, 24) int16
# labels shape  (3, 24, 24) [ 0  1  2  3  4  9 10 11 12 14 15 16 19 20 21 24 49 61 75 84] uint8
# day of years  [ 17  22  47  52  57  72  87 102 112 117 132 147 152 157 172 177 182 187
#  192 197 212 222 227 232 237 242 247 257 262 267 267 272 277 282 282 292
#  292 297 302 312 317 322 327]

# %%
# Our dataset
import pickle
import numpy as np


# file_path = '/home/vuonghn/research/dataset/satellite/arkansas/preprocessed_data/0.pickle'
file_path = "/home/vuonghn/research/dataset/satellite/arkansas/preprocessed_data_aKhoa/0_0.pickle"
with open(file_path, 'rb') as f:
    data = pickle.load(f)

print("keys value ", data.keys())
########
print("img shape ",data['img'].shape,data['img'].dtype)
print("labels shape ",data['labels'].shape, np.unique(data['labels']), data['labels'].dtype)
print("day of years ", data['doy'])
# Out:
# keys value  dict_keys(['img', 'doy', 'labels'])
# img shape  (50, 24, 24, 11) uint16
# labels shape  (1, 24, 24) [0] uint8
# day of years  [8, 13, 23, 36, 43, 46, 48, 58, 63, 76, 86, 88, 91, 98, 108, 121, 148, 158, 168, 171, 176, 181, 183, 191, 198, 208, 211, 223, 228, 231, 233, 236, 241, 243, 251, 258, 261, 271, 273, 281, 283, 291, 293, 303, 306, 308, 311, 326, 331, 343]

# %%
# Out:
# keys value  dict_keys(['x10', 'x20', 'x60', 'day', 'year', 'label'])
# img x10 shape  (24, 24, 24, 6)
# img x20 shape  (24, 12, 12, 6)
# img x60 shape  (24, 4, 4, 3)
# day  [231, 233, 236, 241, 243, 251, 251, 253, 258, 261, 266, 271, 273, 281, 283, 291, 293, 303, 306, 308, 311, 326, 331, 343]
# year  ['2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023', '2023']
# label  (24, 24, 24)
